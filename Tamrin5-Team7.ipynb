# %% [markdown]
# Team7: Hediye Kianfar, Fatemeh Khoshian, Negin Rahmani

# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

print('Libraries loaded.')
# Out:
# Libraries loaded.

# %% [markdown]
# # Example 1: Simple use of algorithm

# %% [markdown]
# ## Creating Dataset

# %%
basket_lists = [['Milk', 'Onion', 'Nutmeg', 'Kidney Beans', 'Eggs', 'Yogurt'],
                ['Dill', 'Onion', 'Nutmeg', 'Kidney Beans', 'Eggs', 'Yogurt'],
                ['Milk', 'Apple', 'Kidney Beans', 'Eggs'],
                ['Milk', 'Unicorn', 'Corn', 'Kidney Beans', 'Yogurt'],
                ['Corn', 'Onion', 'Onion', 'Kidney Beans', 'Ice cream', 'Eggs']]

trans_encoder = TransactionEncoder()

encoded_baskets = trans_encoder.fit(basket_lists).transform(basket_lists)

dataset_df = pd.DataFrame(encoded_baskets, columns= trans_encoder.columns_)

dataset_df
# Out:
#    Apple   Corn   Dill   Eggs  Ice cream  Kidney Beans   Milk  Nutmeg  Onion  \
# 0  False  False  False   True      False          True   True    True   True
# 1  False  False   True   True      False          True  False    True   True
# 2   True  False  False   True      False          True   True   False  False
# 3  False   True  False  False      False          True   True   False  False
# 4  False   True  False   True       True          True  False   False   True
#
#    Unicorn  Yogurt
# 0    False    True
# 1    False    True
# 2    False   False
# 3     True    True
# 4    False   False

# %% [markdown]
# ## Computing support values

# %%
apriori(dataset_df, min_support= 0.6, use_colnames= True)
# Out:
#     support                     itemsets
# 0       0.8                       (Eggs)
# 1       1.0               (Kidney Beans)
# 2       0.6                       (Milk)
# 3       0.6                      (Onion)
# 4       0.6                     (Yogurt)
# 5       0.8         (Eggs, Kidney Beans)
# 6       0.6                (Eggs, Onion)
# 7       0.6         (Milk, Kidney Beans)
# 8       0.6        (Onion, Kidney Beans)
# 9       0.6       (Yogurt, Kidney Beans)
# 10      0.6  (Eggs, Onion, Kidney Beans)

# %% [markdown]
# # Example2: Association rule mining

# %% [markdown]
# ## Loading dataset

# %%
basket_df = pd.read_excel('Data/Online Retail.xlsx')

basket_df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %% [markdown]
# ### Dataset description

# %% [raw]
# Detailed overview of dataset
#
#     - Records in the dataset = 525461 ROWS
#
#     - Columns in the dataset  = 8 COLUMNS
#
#     - InvoiceNo: A 6-digit integral number uniquely assigned to each transaction.
#                  If this code starts with letter 'C', it indicates a cancellation (Nominal)
#
#     - StockCode:  A 5-digit integral number uniquely assigned to each distinct product (Nominal)
#
#     - Description: Product (item) name. (Nominal)
#
#     - Quantity: The quantities of each product (item) per transaction ( Numeric)
#
#     - InvoiceDate:  The day and time when each transaction was generated (Numeric)
#
#     - UnitPrice: Product price per unit in sterling (Numeric)
#
#     - CustomerID:  A 5-digit integral number uniquely assigned to each customer (Nominal)
#
#     - Country:  Name of the country where each customer resides (Nominal)

# %% [markdown]
# ## Some basic exploratory

# %%
basket_df.shape
# Out:
# (541909, 8)

# %%
basket_df.dtypes
# Out:
# InvoiceNo              object
# StockCode              object
# Description            object
# Quantity                int64
# InvoiceDate    datetime64[ns]
# UnitPrice             float64
# CustomerID            float64
# Country                object
# dtype: object

# %%
basket_df.isna().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
canceled = basket_df.loc[basket_df['InvoiceNo'].str.contains('C') == True]

canceled.shape
# Out:
# (9288, 8)

# %% [markdown]
# ## Cleansing dataset

# %%
basket_df['Description'] = basket_df['Description'].str.strip()

#removing canceled records
basket_df.drop(canceled.index, inplace= True)

print(f'{canceled.shape[0]} has removed from dataset, new dataset size is {basket_df.shape[0]}')
# Out:
# 9288 has removed from dataset, new dataset size is 532621

# %% [markdown]
# ## Preparing dataset for analysing

# %% [markdown]
# ### Selecting one region (Germany)

# %%
france_basket = basket_df.loc[basket_df['Country'] == 'France']

france_basket.shape
# Out:
# (8408, 8)

# %% [markdown]
# ### Creating transaction, items set

# %%
basket = []
transaction_nom = []

for transaction, items in france_basket.groupby('InvoiceNo').groups.items():
    
    products = []
    
    transaction_nom.append(transaction)
    
    for item in items:
        
        products.append(str(france_basket.loc[item]['Description']))
    
    ###   
    basket.append(products)

# %% [markdown]
# ### creating binary dataset

# %%
trans_encoder = TransactionEncoder()

encoded_baskets = trans_encoder.fit(basket).transform(basket)

binary_df = pd.DataFrame(encoded_baskets, columns= trans_encoder.columns_, index= transaction_nom)

binary_df
# Out:
#         10002  10120  10125  10135  11001  15036  15039  15044C  15056BL  \
# 536370   True  False  False  False  False  False  False   False    False
# 536852  False  False  False  False  False  False  False   False    False
# 536974  False  False  False  False  False  False  False   False     True
# 537065  False  False  False  False  False  False  False   False    False
# 537463  False  False  False  False  False  False  False   False    False
# ...       ...    ...    ...    ...    ...    ...    ...     ...      ...
# 580986  False  False  False  False  False  False  False   False    False
# 581001  False  False  False  False  False  False  False   False    False
# 581171  False  False  False  False  False  False  False   False    False
# 581279  False  False  False  False  False  False  False   False    False
# 581587  False  False  False  False  False  False  False   False    False
#
#         15056N  ...  90030C  90031  90099  90184B  90184C  90201B  90201C  \
# 536370   False  ...   False  False  False   False   False   False   False
# 536852   False  ...   False  False  False   False   False   False   False
# 536974   False  ...   False  False  False   False   False   False   False
# 537065   False  ...   False  False  False   False   False   False   False
# 537463   False  ...   False  False  False   False   False   False   False
# ...        ...  ...     ...    ...    ...     ...     ...     ...     ...
# 580986   False  ...   False  False  False   False   False   False   False
# 581001   False  ...   False  False  False   False   False   False   False
# 581171   False  ...   False  False  False   False   False   False   False
# 581279   False  ...   False  False  False   False   False   False   False
# 581587   False  ...   False  False  False   False   False   False   False
#
#            C2      M   POST
# 536370  False  False   True
# 536852  False  False   True
# 536974  False  False   True
# 537065  False  False   True
# 537463  False  False   True
# ...       ...    ...    ...
# 580986  False  False   True
# 581001  False  False   True
# 581171  False  False   True
# 581279  False  False   True
# 581587  False  False  False
#
# [392 rows x 1542 columns]

# %% [markdown]
# ### Association extraction(Recommendation based on antecedents)

# %%
frequencies_items = apriori(binary_df, min_support= 0.05, use_colnames= True)
  
rules = association_rules(frequencies_items, metric= "lift", min_threshold= 1)

rules = rules.sort_values(['confidence', 'lift'], ascending= [False, False])

rules.reset_index(inplace= True, drop= True)

rules.head()
# Out:
#       antecedents consequents  antecedent support  consequent support  \
# 0         (20712)      (POST)            0.076531            0.765306
# 1  (22554, 21731)      (POST)            0.053571            0.765306
# 2  (21731, 22556)      (POST)            0.051020            0.765306
# 3  (21086, 21080)     (21094)            0.102041            0.127551
# 4  (21094, 21080)     (21086)            0.102041            0.137755
#
#     support  confidence      lift  leverage  conviction
# 0  0.076531       1.000  1.306667  0.017961         inf
# 1  0.053571       1.000  1.306667  0.012573         inf
# 2  0.051020       1.000  1.306667  0.011974         inf
# 3  0.099490       0.975  7.644000  0.086474   34.897959
# 4  0.099490       0.975  7.077778  0.085433   34.489796

# %% [markdown]
# ### Filtering results

# %%
condition0 = rules.antecedents.apply(lambda x: False if 'POSTAGE' in x else True)

condition1 = rules.consequents.apply(lambda x: False if 'POSTAGE' in x else True)

condition2 = rules['antecedents'].apply(lambda x: len(x) >= 2)

rules.loc[condition0 & condition1 & condition2]
# Out:
#         antecedents consequents  antecedent support  consequent support  \
# 3    (21086, 21080)     (21094)            0.102041            0.127551
# 4    (21094, 21080)     (21086)            0.102041            0.137755
# 53   (22726, 22728)     (22727)            0.073980            0.094388
# 54   (22727, 22728)     (22726)            0.073980            0.096939
# 81   (21086, 21094)     (21080)            0.122449            0.132653
# 84   (22726, 22727)     (22728)            0.079082            0.102041
# 109  (22556, 22551)     (22554)            0.089286            0.170918
# 143  (22554, 22556)     (22551)            0.102041            0.137755
# 147  (22554, 22551)     (22556)            0.104592            0.168367
#
#       support  confidence      lift  leverage  conviction
# 3    0.099490    0.975000  7.644000  0.086474   34.897959
# 4    0.099490    0.975000  7.077778  0.085433   34.489796
# 53   0.063776    0.862069  9.133271  0.056793    6.565689
# 54   0.063776    0.862069  8.892922  0.056604    6.547194
# 81   0.099490    0.812500  6.125000  0.083247    4.625850
# 84   0.063776    0.806452  7.903226  0.055706    4.639456
# 109  0.068878    0.771429  4.513433  0.053617    3.627232
# 143  0.068878    0.675000  4.900000  0.054821    2.653061
# 147  0.068878    0.658537  3.911308  0.051268    2.435496

# %% [markdown]
# # Excersice1

# %% [raw]
# در قواعد بدست آمده از کد کالا استفاده شده است. قواعد را با استفاده از توضیح هر کد کالا برای کاربرقابل فهم کنید. به عبارت دیگر بجای کد کالا از توضیح یا نام کالا استفاده کنید.

# %% [markdown]
# # Excersize2

# %% [raw]
# بررسی کنید قواعد بدست آمده از تحلیل سبد خرید فرانسوی های چقدر مشابه قوانین سبد خرید سوئیس هاست.
# به عبارت دیگر با چه احتمالی می توان قواعد بدست آمده از تحلیل سبد خرید فرانسویان را به سبد خرید سوئیسی ها تعمیم داد.

# %% [markdown]
# Select one region: Switzerland

# %%
switzerland_basket = basket_df.loc[basket_df['Country'] == 'Switzerland']

# %%
basket2 = []
transaction2 = []

for transaction, items in switzerland_basket.groupby('InvoiceNo').groups.items():
    products2 = []
    transaction2.append(transaction)
    for item in items:
        products2.append(str(switzerland_basket.loc[item]['Description']))
    basket2.append(products2)

# %%
trans_encoder = TransactionEncoder()
encoded_baskets2 = trans_encoder.fit(basket2).transform(basket2)
binary_df2 = pd.DataFrame(encoded_baskets2, columns= trans_encoder.columns_, index= transaction2)
binary_df2
# Out:
#         10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# 536858                   False                       False
# 539488                   False                       False
# 541518                   False                       False
# 541569                   False                       False
# 542586                   False                       False
# 543180                   False                       False
# 543181                   False                       False
# 544931                   False                       False
# 545034                   False                       False
# 545084                   False                       False
# 546134                   False                       False
# 547815                   False                       False
# 548212                    True                       False
# 550188                   False                       False
# 550281                   False                       False
# 550671                   False                       False
# 550899                   False                       False
# 552013                   False                        True
# 552329                   False                       False
# 555147                   False                       False
# 555943                   False                       False
# 556415                   False                       False
# 558041                   False                       False
# 558089                   False                       False
# 558639                   False                       False
# 559372                   False                       False
# 560245                   False                       False
# 561116                   False                       False
# 561332                   False                       False
# 561898                    True                       False
# 562046                   False                        True
# 562882                   False                       False
# 563756                   False                       False
# 565785                   False                       False
# 566756                   False                       False
# 566916                   False                       False
# 567642                   False                       False
# 567721                   False                       False
# 568650                   False                       False
# 568950                   False                       False
# 569653                    True                       False
# 570521                   False                       False
# 570714                   False                       False
# 572567                   False                       False
# 572770                   False                       False
# 572896                   False                       False
# 573286                   False                       False
# 573290                   False                       False
# 574740                   False                       False
# 575734                   False                       False
# 577157                   False                       False
# 578099                   False                       False
# 578123                   False                       False
# 579259                   False                       False
#
#         12 PENCIL SMALL TUBE WOODLAND  12 PENCILS SMALL TUBE SKULL  \
# 536858                          False                        False
# 539488                          False                        False
# 541518                          False                        False
# 541569                           True                        False
# 542586                          False                        False
# 543180                          False                        False
# 543181                          False                        False
# 544931                          False                        False
# 545034                          False                        False
# 545084                          False                        False
# 546134                          False                        False
# 547815                          False                        False
# 548212                          False                        False
# 550188                          False                        False
# 550281                          False                        False
# 550671                          False                        False
# 550899                          False                        False
# 552013                          False                        False
# 552329                          False                        False
# 555147                          False                        False
# 555943                          False                        False
# 556415                          False                        False
# 558041                          False                        False
# 558089                          False                        False
# 558639                          False                        False
# 559372                          False                        False
# 560245                          False                        False
# 561116                          False                        False
# 561332                          False                        False
# 561898                          False                        False
# 562046                          False                        False
# 562882                          False                        False
# 563756                          False                        False
# 565785                          False                        False
# 566756                          False                        False
# 566916                          False                        False
# 567642                          False                        False
# 567721                          False                        False
# 568650                          False                        False
# 568950                          False                        False
# 569653                          False                        False
# 570521                          False                        False
# 570714                           True                        False
# 572567                          False                         True
# 572770                          False                        False
# 572896                          False                        False
# 573286                          False                        False
# 573290                          False                        False
# 574740                          False                        False
# 575734                          False                        False
# 577157                          False                        False
# 578099                          False                        False
# 578123                          False                        False
# 579259                          False                        False
#
#         12 PENCILS TALL TUBE POSY  12 PENCILS TALL TUBE RED RETROSPOT  \
# 536858                      False                               False
# 539488                      False                               False
# 541518                      False                               False
# 541569                      False                               False
# 542586                      False                               False
# 543180                      False                               False
# 543181                      False                               False
# 544931                      False                               False
# 545034                      False                               False
# 545084                      False                               False
# 546134                      False                               False
# 547815                      False                               False
# 548212                      False                               False
# 550188                      False                               False
# 550281                      False                               False
# 550671                      False                               False
# 550899                      False                               False
# 552013                      False                               False
# 552329                      False                               False
# 555147                      False                               False
# 555943                      False                               False
# 556415                      False                               False
# 558041                      False                               False
# 558089                      False                               False
# 558639                      False                               False
# 559372                      False                               False
# 560245                      False                               False
# 561116                      False                               False
# 561332                      False                               False
# 561898                       True                               False
# 562046                      False                               False
# 562882                      False                               False
# 563756                      False                               False
# 565785                      False                               False
# 566756                      False                               False
# 566916                      False                               False
# 567642                      False                               False
# 567721                      False                               False
# 568650                      False                               False
# 568950                      False                               False
# 569653                      False                               False
# 570521                      False                               False
# 570714                      False                               False
# 572567                      False                                True
# 572770                      False                               False
# 572896                      False                               False
# 573286                      False                               False
# 573290                      False                               False
# 574740                      False                               False
# 575734                      False                               False
# 577157                      False                               False
# 578099                      False                               False
# 578123                      False                               False
# 579259                      False                               False
#
#         12 PENCILS TALL TUBE SKULLS  12 PENCILS TALL TUBE WOODLAND  \
# 536858                        False                          False
# 539488                        False                          False
# 541518                        False                          False
# 541569                        False                          False
# 542586                        False                          False
# 543180                        False                          False
# 543181                        False                          False
# 544931                        False                          False
# 545034                        False                          False
# 545084                        False                          False
# 546134                        False                          False
# 547815                        False                          False
# 548212                        False                          False
# 550188                        False                          False
# 550281                        False                          False
# 550671                        False                          False
# 550899                        False                          False
# 552013                        False                          False
# 552329                        False                          False
# 555147                        False                          False
# 555943                        False                          False
# 556415                        False                          False
# 558041                        False                          False
# 558089                        False                          False
# 558639                        False                          False
# 559372                        False                          False
# 560245                        False                          False
# 561116                        False                          False
# 561332                        False                          False
# 561898                        False                          False
# 562046                        False                          False
# 562882                        False                          False
# 563756                        False                          False
# 565785                        False                          False
# 566756                        False                          False
# 566916                        False                          False
# 567642                        False                          False
# 567721                        False                          False
# 568650                         True                           True
# 568950                        False                          False
# 569653                        False                          False
# 570521                        False                          False
# 570714                        False                          False
# 572567                        False                          False
# 572770                        False                          False
# 572896                        False                          False
# 573286                        False                          False
# 573290                        False                          False
# 574740                        False                          False
# 575734                        False                          False
# 577157                        False                          False
# 578099                        False                          False
# 578123                        False                          False
# 579259                        False                          False
#
#         12 RED ROSE PEG PLACE SETTINGS  15CM CHRISTMAS GLASS BALL 20 LIGHTS  \
# 536858                           False                                False
# 539488                           False                                False
# 541518                           False                                False
# 541569                           False                                False
# 542586                           False                                False
# 543180                           False                                False
# 543181                           False                                False
# 544931                           False                                False
# 545034                           False                                False
# 545084                           False                                False
# 546134                           False                                False
# 547815                           False                                False
# 548212                           False                                False
# 550188                           False                                False
# 550281                           False                                False
# 550671                           False                                False
# 550899                           False                                False
# 552013                           False                                False
# 552329                           False                                False
# 555147                           False                                False
# 555943                           False                                False
# 556415                           False                                False
# 558041                           False                                False
# 558089                           False                                False
# 558639                           False                                False
# 559372                           False                                False
# 560245                           False                                False
# 561116                           False                                False
# 561332                           False                                False
# 561898                           False                                False
# 562046                           False                                 True
# 562882                           False                                False
# 563756                           False                                False
# 565785                           False                                False
# 566756                           False                                False
# 566916                           False                                False
# 567642                           False                                False
# 567721                            True                                False
# 568650                           False                                False
# 568950                           False                                False
# 569653                           False                                False
# 570521                           False                                False
# 570714                           False                                False
# 572567                           False                                False
# 572770                           False                                False
# 572896                           False                                False
# 573286                           False                                False
# 573290                           False                                False
# 574740                           False                                False
# 575734                           False                                False
# 577157                           False                                False
# 578099                           False                                False
# 578123                           False                                False
# 579259                           False                                False
#
#         ...  WRAP MAGIC FOREST  WRAP PAISLEY PARK  WRAP PINK FAIRY CAKES  \
# 536858  ...              False              False                  False
# 539488  ...              False              False                  False
# 541518  ...              False              False                  False
# 541569  ...              False              False                  False
# 542586  ...              False              False                  False
# 543180  ...              False              False                  False
# 543181  ...              False              False                  False
# 544931  ...              False              False                  False
# 545034  ...              False              False                  False
# 545084  ...              False              False                  False
# 546134  ...              False              False                  False
# 547815  ...              False              False                  False
# 548212  ...              False              False                  False
# 550188  ...              False              False                  False
# 550281  ...              False              False                  False
# 550671  ...              False              False                  False
# 550899  ...              False              False                  False
# 552013  ...              False              False                  False
# 552329  ...              False              False                  False
# 555147  ...              False              False                  False
# 555943  ...              False              False                  False
# 556415  ...              False              False                  False
# 558041  ...              False              False                  False
# 558089  ...              False              False                  False
# 558639  ...              False              False                  False
# 559372  ...              False              False                  False
# 560245  ...              False              False                  False
# 561116  ...              False              False                  False
# 561332  ...              False              False                  False
# 561898  ...              False              False                  False
# 562046  ...              False              False                  False
# 562882  ...              False              False                  False
# 563756  ...              False              False                  False
# 565785  ...              False              False                  False
# 566756  ...              False              False                  False
# 566916  ...              False              False                  False
# 567642  ...              False              False                  False
# 567721  ...              False              False                  False
# 568650  ...               True              False                  False
# 568950  ...              False              False                  False
# 569653  ...              False              False                  False
# 570521  ...              False              False                  False
# 570714  ...              False              False                  False
# 572567  ...              False               True                   True
# 572770  ...              False              False                  False
# 572896  ...              False              False                  False
# 573286  ...              False              False                  False
# 573290  ...              False              False                  False
# 574740  ...              False              False                  False
# 575734  ...              False              False                  False
# 577157  ...              False              False                  False
# 578099  ...              False              False                  False
# 578123  ...              False              False                  False
# 579259  ...              False              False                  False
#
#         WRAP RED APPLES  WRAP RED VINTAGE DOILY  WRAP SUKI AND FRIENDS  \
# 536858            False                   False                  False
# 539488            False                   False                  False
# 541518            False                   False                  False
# 541569            False                   False                  False
# 542586            False                   False                  False
# 543180            False                   False                  False
# 543181            False                   False                  False
# 544931            False                   False                  False
# 545034            False                   False                  False
# 545084            False                   False                  False
# 546134            False                   False                  False
# 547815            False                   False                  False
# 548212            False                   False                  False
# 550188            False                   False                  False
# 550281            False                   False                  False
# 550671            False                   False                  False
# 550899            False                   False                  False
# 552013            False                   False                  False
# 552329            False                   False                  False
# 555147            False                   False                  False
# 555943            False                   False                  False
# 556415            False                   False                  False
# 558041            False                   False                  False
# 558089            False                   False                   True
# 558639            False                   False                  False
# 559372            False                   False                  False
# 560245            False                   False                  False
# 561116            False                   False                  False
# 561332            False                   False                  False
# 561898            False                   False                  False
# 562046            False                   False                   True
# 562882            False                   False                  False
# 563756            False                   False                  False
# 565785            False                   False                  False
# 566756            False                   False                  False
# 566916            False                   False                  False
# 567642            False                   False                  False
# 567721            False                   False                  False
# 568650             True                   False                  False
# 568950            False                   False                  False
# 569653             True                   False                   True
# 570521            False                   False                  False
# 570714            False                   False                  False
# 572567             True                    True                  False
# 572770            False                   False                  False
# 572896            False                   False                  False
# 573286            False                   False                  False
# 573290            False                   False                  False
# 574740            False                   False                  False
# 575734            False                   False                  False
# 577157             True                   False                  False
# 578099            False                   False                  False
# 578123            False                   False                  False
# 579259            False                   False                  False
#
#         YELLOW METAL CHICKEN HEART  YOU'RE CONFUSING ME METAL SIGN  \
# 536858                       False                           False
# 539488                       False                           False
# 541518                       False                           False
# 541569                       False                           False
# 542586                       False                           False
# 543180                       False                           False
# 543181                       False                           False
# 544931                        True                           False
# 545034                       False                           False
# 545084                       False                           False
# 546134                       False                           False
# 547815                       False                           False
# 548212                       False                           False
# 550188                       False                           False
# 550281                       False                           False
# 550671                       False                           False
# 550899                       False                           False
# 552013                       False                           False
# 552329                       False                           False
# 555147                       False                           False
# 555943                       False                           False
# 556415                       False                            True
# 558041                       False                           False
# 558089                       False                           False
# 558639                       False                           False
# 559372                       False                           False
# 560245                       False                           False
# 561116                       False                           False
# 561332                       False                           False
# 561898                       False                           False
# 562046                       False                           False
# 562882                       False                           False
# 563756                       False                           False
# 565785                       False                           False
# 566756                       False                           False
# 566916                       False                           False
# 567642                       False                           False
# 567721                       False                           False
# 568650                       False                           False
# 568950                       False                           False
# 569653                       False                           False
# 570521                       False                           False
# 570714                       False                           False
# 572567                       False                           False
# 572770                       False                           False
# 572896                       False                           False
# 573286                       False                           False
# 573290                       False                           False
# 574740                       False                           False
# 575734                       False                           False
# 577157                       False                           False
# 578099                       False                           False
# 578123                       False                           False
# 579259                       False                           False
#
#         ZINC METAL HEART DECORATION  ZINC WILLIE WINKIE  CANDLE STICK
# 536858                        False                             False
# 539488                        False                             False
# 541518                        False                             False
# 541569                        False                             False
# 542586                        False                             False
# 543180                        False                             False
# 543181                        False                             False
# 544931                        False                             False
# 545034                        False                             False
# 545084                        False                             False
# 546134                        False                             False
# 547815                        False                             False
# 548212                        False                             False
# 550188                        False                             False
# 550281                        False                             False
# 550671                        False                             False
# 550899                        False                             False
# 552013                        False                             False
# 552329                        False                             False
# 555147                        False                             False
# 555943                        False                             False
# 556415                        False                             False
# 558041                        False                             False
# 558089                        False                             False
# 558639                        False                             False
# 559372                        False                             False
# 560245                         True                             False
# 561116                        False                             False
# 561332                        False                             False
# 561898                         True                              True
# 562046                        False                             False
# 562882                        False                             False
# 563756                        False                             False
# 565785                        False                             False
# 566756                        False                             False
# 566916                        False                             False
# 567642                        False                             False
# 567721                        False                             False
# 568650                        False                             False
# 568950                        False                             False
# 569653                        False                             False
# 570521                        False                             False
# 570714                        False                             False
# 572567                        False                             False
# 572770                        False                             False
# 572896                        False                             False
# 573286                        False                             False
# 573290                        False                             False
# 574740                        False                             False
# 575734                        False                             False
# 577157                        False                              True
# 578099                        False                             False
# 578123                        False                             False
# 579259                        False                             False
#
# [54 rows x 987 columns]

# %%
frequencies_items2 = apriori(binary_df2, min_support= 0.06, use_colnames= True)
rules2 = association_rules(frequencies_items2, metric= "lift", min_threshold= 1)
rules2 = rules2.sort_values(['confidence', 'lift'], ascending= [False, False])
rules2.reset_index(inplace= True, drop= True)
rules2.head()
# Out:
#                                          antecedents  \
# 0                             (MINI JIGSAW SPACEBOY)
# 1                           (MINI JIGSAW DOLLY GIRL)
# 2                           (SPACEBOY CHILDRENS CUP)
# 3                          (SPACEBOY CHILDRENS BOWL)
# 4  (PLASTERS IN TIN SPACEBOY, RED RETROSPOT CHARL...
#
#                  consequents  antecedent support  consequent support  \
# 0   (MINI JIGSAW DOLLY GIRL)            0.074074            0.074074
# 1     (MINI JIGSAW SPACEBOY)            0.074074            0.074074
# 2  (SPACEBOY CHILDRENS BOWL)            0.074074            0.074074
# 3   (SPACEBOY CHILDRENS CUP)            0.074074            0.074074
# 4   (STRAWBERRY SHOPPER BAG)            0.074074            0.074074
#
#     support  confidence  lift  leverage  conviction
# 0  0.074074         1.0  13.5  0.068587         inf
# 1  0.074074         1.0  13.5  0.068587         inf
# 2  0.074074         1.0  13.5  0.068587         inf
# 3  0.074074         1.0  13.5  0.068587         inf
# 4  0.074074         1.0  13.5  0.068587         inf

# %%
condition_02 = rules2.antecedents.apply(lambda x: False if 'POSTAGE' in x else True)
condition_12 = rules2.consequents.apply(lambda x: False if 'POSTAGE' in x else True)
condition_22 = rules2['antecedents'].apply(lambda x: len(x) >= 2)
rules2.loc[condition_02 & condition_12 & condition_22]
# Out:
#                                             antecedents  \
# 4     (PLASTERS IN TIN SPACEBOY, RED RETROSPOT CHARL...
# 6     (WOODLAND MINI BACKPACK, PLASTERS IN TIN WOODL...
# 8     (CHILDRENS CUTLERY CIRCUS PARADE, PLASTERS IN ...
# 9     (SPACEBOY BABY GIFT SET, RED RETROSPOT CHARLOT...
# 10    (LUNCH BAG APPLE DESIGN, WATERING CAN BLUE ELE...
# ...                                                 ...
# 2772  (PLASTERS IN TIN WOODLAND ANIMALS, PLASTERS IN...
# 2773  (PLASTERS IN TIN WOODLAND ANIMALS, PLASTERS IN...
# 2774  (PLASTERS IN TIN WOODLAND ANIMALS, PLASTERS IN...
# 2775  (PLASTERS IN TIN WOODLAND ANIMALS, PLASTERS IN...
# 2776  (PLASTERS IN TIN WOODLAND ANIMALS, PLASTERS IN...
#
#                                             consequents  antecedent support  \
# 4                              (STRAWBERRY SHOPPER BAG)            0.074074
# 6                              (SPACEBOY MINI BACKPACK)            0.074074
# 8     (SPACEBOY BABY GIFT SET, RED RETROSPOT CHARLOT...            0.074074
# 9     (CHILDRENS CUTLERY CIRCUS PARADE, PLASTERS IN ...            0.074074
# 10    (LUNCH BAG RED RETROSPOT, WATERING CAN PINK BU...            0.074074
# ...                                                 ...                 ...
# 2772                                 (JUMBO BAG APPLES)            0.240741
# 2773  (ROUND SNACK BOXES SET OF4 WOODLAND, SPACEBOY ...            0.240741
# 2774                            (DOORMAT RED RETROSPOT)            0.240741
# 2775                           (SPACEBOY BIRTHDAY CARD)            0.240741
# 2776                         (REGENCY CAKESTAND 3 TIER)            0.240741
#
#       consequent support   support  confidence       lift  leverage  \
# 4               0.074074  0.074074    1.000000  13.500000  0.068587
# 6               0.074074  0.074074    1.000000  13.500000  0.068587
# 8               0.074074  0.074074    1.000000  13.500000  0.068587
# 9               0.074074  0.074074    1.000000  13.500000  0.068587
# 10              0.074074  0.074074    1.000000  13.500000  0.068587
# ...                  ...       ...         ...        ...       ...
# 2772            0.129630  0.074074    0.307692   2.373626  0.042867
# 2773            0.129630  0.074074    0.307692   2.373626  0.042867
# 2774            0.166667  0.074074    0.307692   1.846154  0.033951
# 2775            0.203704  0.074074    0.307692   1.510490  0.025034
# 2776            0.222222  0.074074    0.307692   1.384615  0.020576
#
#       conviction
# 4            inf
# 6            inf
# 8            inf
# 9            inf
# 10           inf
# ...          ...
# 2772    1.257202
# 2773    1.257202
# 2774    1.203704
# 2775    1.150206
# 2776    1.123457
#
# [1571 rows x 9 columns]
