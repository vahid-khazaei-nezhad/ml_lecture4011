# %% [markdown]
# # Home work no.2
# >## professor : Dr. Vahid Khazaei nezhad
# # Team Members :
# - Saeed Tizkar
# - Pooriya Amini
# - Mohammad Elahi

# %% [markdown]
# # Import and load dataset

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df_temp = pd.read_excel('Data/converted.xlsx', engine='openpyxl', header=None, usecols=[2,4,6,8,10], names=['guide_number', 'copy_number',  'title', 'document_number','record_number' ], skiprows=8)
df.head(20)
# Out:
#                   guide_number  copy_number  \
# 0                      ‭‭ص‌۱۶۸          4.0
# 1                ‭‭درادن‍ ه‌در          1.0
# 2                ‭‭درادن‍ ه‌در          3.0
# 3                ‭‭درادن‍ ه‌در          1.0
# 4                ‭‭درادن‍ ه‌در          1.0
# 5                ‭‭درادن‍ ه‌در          1.0
# 6                ‭‭درادن‍ ه‌در          1.0
# 7              ‭‭00،۰۰،۰۰۰۰،۰۰          1.0
# 8        ‭‭0A،۳۷۲،/ن‌۹م‌۶،۱۳۷۳          2.0
# 9                       ‭‭ARSH         19.0
# 10      ‭‭A،/۱ ک‌ ۱۳۷،۴۲۸،۱۳۹۴          1.0
# 11       ‭‭BBR،۲۳۸،/ف‌۲ر۵،۱۳۸۷          1.0
# 12       ‭‭BBR،۹۰۱،/ق‌۶د۴،۱۳۸۶          1.0
# 13  ‭‭BBR،۱۳۹۲،/ف‌ل‍ا۵ب‌۴،۱۳۹۰          1.0
# 14      ‭‭BBR،۱۱۳۴،/ق‌۲ر۵،۱۳۸۹          1.0
# 15     ‭‭BC،۱۷۷،/و۲ف‌ل‍ا۸،۱۳۸۸          1.0
# 16       ‭‭BC،۱۷۷،/ک‌۹م‌۹،۱۳۸۳          1.0
# 17     ‭‭BD،۴۱۸/۳،/م‌۵ف‌۸،۱۳۸۹          1.0
# 18     ‭‭BF،۴۴۲،/د ۸۶ ه‌۹،۱۳۹۴          1.0
# 19        ‭‭BF،۶۴۱،/آ۷ت‌۹،۱۳۹۰          1.0
#
#                                                 title document_number  \
# 0   ‮ح‍ل‌ م‍س‍ائ‍ل‌ ف‍ی‍زی‍ک‌ ب‍رای‌ ع‍ل‍وم‌ زی‍س‍...            ۲۳۵۹
# 1   ‮آش‍ن‍ای‍ی‌ ب‍ا م‍س‍ی‍ری‍اب‌ ه‍ای‌ م‍ی‍ک‍روت‍ی‍ک‌            ۲۵۹۳
# 2   ‮ک‍ش‍ت‌ و پ‍رورش‌ گ‍ی‍اه‍ان‌ داروی‍ی‌ : آم‍ادگ...            ۲۶۰۰
# 3                    ‮ب‍ی‍وت‍ک‍ن‍ول‍وژی‌ م‍ی‍ک‍روب‍ی‌            ۲۶۱۶
# 4                         ‮زی‍س‍ت‌ ف‍ن‍اوری‌ غ‍ذای‍ی‌            ۲۶۲۷
# 5   ‮ع‍وام‍ل‌ ب‍ی‍م‍اری‌ زای‌ م‍ش‍ت‍رک‌ ب‍ی‍ن‌ ان‍...            ۲۶۳۱
# 6   ‮ف‍ی‍زی‍ک‌ پ‍ای‍ه‌ : ال‍ک‍ت‍ری‍س‍ی‍ت‍ه‌ م‍غ‍ن‍...            ۲۲۵۱
# 7                         ‮ال‍ک‍ت‍رون‍ی‍ک‌ ص‍ن‍ع‍ت‍ی‌            ۲۱۹۸
# 8                         ‮م‍ع‍ادلات‌ دی‍ف‍ران‍س‍ی‍ل‌            ۱۵۶۶
# 9     ‮ک‍ن‍ک‍ور ک‍ارش‍ن‍اس‍ی‌ ارش‍د - راه‍ی‍ان‌ ارش‍د            ۲۴۱۲
# 10                   ‮اول‍ی‍ن‌ ه‍زار ک‍ل‍م‍ه‌ ی‌ م‍ن‌            ۲۱۳۸
# 11                     ‮رس‍ائ‍ل‌ ف‍ل‍س‍ف‍ی‌ ف‍اراب‍ی‌            ۱۴۱۷
# 12  ‮دره‌ ال‍ت‍اج‌ (ب‍خ‍ش‌ ح‍ک‍م‍ت‌ ع‍م‍ل‍ی‌ و س‍ی...            ۱۳۳۷
# 13  ‮آغ‍از ح‍ک‍م‍ت‌؛ درس‍ن‍ام‍ه‌ ف‍ل‍س‍ف‍ه‌ ب‍ر اس...            ۱۳۴۴
# 14  ‮رس‍ائ‍ل‌ ع‍رف‍ان‍ی‌ و ف‍ل‍س‍ف‍ی‌ ح‍ک‍ی‍م‌ ق‍ا...            ۱۳۳۳
# 15  ‮ان‍دی‍ش‍ی‍دن‌، ف‍ره‍ن‍گ‌ ک‍وچ‍ک‌ س‍ن‍ج‍ش‍گ‍را...            ۱۴۶۵
# 16  ‮م‍ی‍ک‍روب‍ی‍ول‍وژی‌ خ‍اک‌(ره‍ی‍اف‍ت‍ی‌ ک‍ن‍ج‍...             ۶۶۳
# 17    ‮ف‍ل‍س‍ف‍ه‌ ذه‍ن‌(از ک‍ت‍اب‌ ف‍ه‍م‌ ف‍ل‍س‍ف‍ه‌)            ۱۳۳۶
# 18                       ‮ه‍ن‍ر ش‍ف‍اف‌ ان‍دی‍ش‍ی‍دن‌            ۱۵۷۶
# 19                ‮ت‍و ه‍م‍ان‍ی‌ ک‍ه‌ م‍ی‌ ان‍دی‍ش‍ی‌             ۴۹۰
#
#     record_number
# 0          2594.0
# 1          2729.0
# 2          2736.0
# 3          2752.0
# 4          2763.0
# 5          2767.0
# 6          2487.0
# 7          2434.0
# 8          1755.0
# 9          2648.0
# 10         2364.0
# 11         1603.0
# 12         1523.0
# 13         1530.0
# 14         1519.0
# 15         1651.0
# 16          720.0
# 17         1522.0
# 18         1766.0
# 19          534.0

# %% [markdown]
# # Simple EDA
# >## Checking size of dataset

# %%
df.shape
# Out:
# (2532, 5)

# %% [markdown]
# >## Checking data types

# %%
df.dtypes
# Out:
# guide_number        object
# copy_number        float64
# title               object
# document_number     object
# record_number      float64
# dtype: object

# %% [markdown]
# >## Drop NAN rows

# %%
df = df_temp.dropna(how='all')
df
# Out:
#                 guide_number  copy_number  \
# 0                    ‭‭ص‌۱۶۸          4.0
# 4              ‭‭درادن‍ ه‌در          1.0
# 8              ‭‭درادن‍ ه‌در          3.0
# 12             ‭‭درادن‍ ه‌در          1.0
# 16             ‭‭درادن‍ ه‌در          1.0
# ...                      ...          ...
# 10328  ‭‭Z،۵۲/۵،/و۳۷م‌۶،۱۳۸۳          1.0
# 10332   ‭‭Z،۵۲/۵،/ع‌۷آ۸،۱۳۹۰          1.0
# 10336    ‭‭Z،۱،/م‌۳۲۵گ‌،۱۳۷۵          1.0
# 10340  ‭‭اد،۳۰۰،/ب‌۴ب‌۲،۱۳۹۲          2.0
# 10343                    NaN       6161.0
#
#                                                    title document_number  \
# 0      ‮ح‍ل‌ م‍س‍ائ‍ل‌ ف‍ی‍زی‍ک‌ ب‍رای‌ ع‍ل‍وم‌ زی‍س‍...            ۲۳۵۹
# 4      ‮آش‍ن‍ای‍ی‌ ب‍ا م‍س‍ی‍ری‍اب‌ ه‍ای‌ م‍ی‍ک‍روت‍ی‍ک‌            ۲۵۹۳
# 8      ‮ک‍ش‍ت‌ و پ‍رورش‌ گ‍ی‍اه‍ان‌ داروی‍ی‌ : آم‍ادگ...            ۲۶۰۰
# 12                      ‮ب‍ی‍وت‍ک‍ن‍ول‍وژی‌ م‍ی‍ک‍روب‍ی‌            ۲۶۱۶
# 16                           ‮زی‍س‍ت‌ ف‍ن‍اوری‌ غ‍ذای‍ی‌            ۲۶۲۷
# ...                                                  ...             ...
# 10328                                       ‮ک‍ل‍ی‍د ورد            ۲۰۵۹
# 10332                       ‮آم‍وزش‌ ت‍ص‍وی‍ری‌ ورد۲۰۱۰               ۳۰
# 10336                   ‮درم‍ان‌ ب‍ا گ‍ی‍اه‍ان‌ داروی‍ی‌            ۲۲۰۹
# 10340                               ‮ب‍اغ‌ ب‍ی‌ ان‍ت‍ه‍ا            ۱۴۰۹
# 10343                      جمـــــــــــــع کــل نســــخ             NaN
#
#        record_number
# 0             2594.0
# 4             2729.0
# 8             2736.0
# 12            2752.0
# 16            2763.0
# ...              ...
# 10328         2284.0
# 10332           37.0
# 10336         2445.0
# 10340         1595.0
# 10343            NaN
#
# [2532 rows x 5 columns]

# %% [markdown]
# >## Reset the rows indexes

# %%
df.reset_index(inplace=True, drop=True)
df
# Out:
#                guide_number  copy_number  \
# 0                   ‭‭ص‌۱۶۸          4.0
# 1             ‭‭درادن‍ ه‌در          1.0
# 2             ‭‭درادن‍ ه‌در          3.0
# 3             ‭‭درادن‍ ه‌در          1.0
# 4             ‭‭درادن‍ ه‌در          1.0
# ...                     ...          ...
# 2527  ‭‭Z،۵۲/۵،/و۳۷م‌۶،۱۳۸۳          1.0
# 2528   ‭‭Z،۵۲/۵،/ع‌۷آ۸،۱۳۹۰          1.0
# 2529    ‭‭Z،۱،/م‌۳۲۵گ‌،۱۳۷۵          1.0
# 2530  ‭‭اد،۳۰۰،/ب‌۴ب‌۲،۱۳۹۲          2.0
# 2531                    NaN       6161.0
#
#                                                   title document_number  \
# 0     ‮ح‍ل‌ م‍س‍ائ‍ل‌ ف‍ی‍زی‍ک‌ ب‍رای‌ ع‍ل‍وم‌ زی‍س‍...            ۲۳۵۹
# 1     ‮آش‍ن‍ای‍ی‌ ب‍ا م‍س‍ی‍ری‍اب‌ ه‍ای‌ م‍ی‍ک‍روت‍ی‍ک‌            ۲۵۹۳
# 2     ‮ک‍ش‍ت‌ و پ‍رورش‌ گ‍ی‍اه‍ان‌ داروی‍ی‌ : آم‍ادگ...            ۲۶۰۰
# 3                      ‮ب‍ی‍وت‍ک‍ن‍ول‍وژی‌ م‍ی‍ک‍روب‍ی‌            ۲۶۱۶
# 4                           ‮زی‍س‍ت‌ ف‍ن‍اوری‌ غ‍ذای‍ی‌            ۲۶۲۷
# ...                                                 ...             ...
# 2527                                       ‮ک‍ل‍ی‍د ورد            ۲۰۵۹
# 2528                       ‮آم‍وزش‌ ت‍ص‍وی‍ری‌ ورد۲۰۱۰               ۳۰
# 2529                   ‮درم‍ان‌ ب‍ا گ‍ی‍اه‍ان‌ داروی‍ی‌            ۲۲۰۹
# 2530                               ‮ب‍اغ‌ ب‍ی‌ ان‍ت‍ه‍ا            ۱۴۰۹
# 2531                      جمـــــــــــــع کــل نســــخ             NaN
#
#       record_number
# 0            2594.0
# 1            2729.0
# 2            2736.0
# 3            2752.0
# 4            2763.0
# ...             ...
# 2527         2284.0
# 2528           37.0
# 2529         2445.0
# 2530         1595.0
# 2531            NaN
#
# [2532 rows x 5 columns]

# %% [markdown]
# # Exercise

# %% [markdown]
# فراوانی سال انتشار کتاب های موجود در کتابخانه را بدست بیاورید. به عنوان مثال بگوئید در کتابخانه چند کتاب سال انتشارشان مربوط به سال 1375 است؟
# این مقدار را برای همه سال هایی که  نسخه از آن در کتابخانه موجود است بدست بیاورید.

# %% [markdown]
# # Get year from guidance

# %%
guide = df['guide_number']
year = []
for i in range(0, 2530):
    try:
        if guide[i][-5] == '،':
            year.append(guide[i][-4:])
    except:
        pass
# convert 1378 to ۱۳۷۸
for i in range(0, len(year)):
    if year[i] == "1378":
        year[i] = "۱۳۷۸"
yeardf = pd.DataFrame(year)
yeardf
# Out:
#          0
# 0     ۱۳۷۳
# 1     ۱۳۹۴
# 2     ۱۳۸۷
# 3     ۱۳۸۶
# 4     ۱۳۹۰
# ...    ...
# 2456  ۱۳۹۰
# 2457  ۱۳۸۳
# 2458  ۱۳۸۳
# 2459  ۱۳۹۰
# 2460  ۱۳۷۵
#
# [2461 rows x 1 columns]

# %% [markdown]
# # Find frequancy of years

# %%
unique, frequency = np.unique(year, return_index=True)
count = np.asarray((unique, frequency))
yearFreq = pd.DataFrame(count).T
yearFreq.head()
# Out:
#       0    1
# 0  ۱۱۲۷  630
# 1  ۱۱۲۸  622
# 2  ۱۳۳۷  818
# 3  ۱۳۴۵  557
# 4  ۱۳۴۸  926

# %% [markdown]
# # Drop some rows

# %%
yearFreq.drop([0, 1, 47, 48, 49, 50], inplace=True)
yearFreq.head()
# Out:
#       0    1
# 2  ۱۳۳۷  818
# 3  ۱۳۴۵  557
# 4  ۱۳۴۸  926
# 5  ۱۳۵۵  620
# 6  ۱۳۵۷  766

# %% [markdown]
# # Change header

# %%
yearFreq.columns = ['year', 'frequency']
yearFreq.head()
# Out:
#    year frequency
# 2  ۱۳۳۷       818
# 3  ۱۳۴۵       557
# 4  ۱۳۴۸       926
# 5  ۱۳۵۵       620
# 6  ۱۳۵۷       766

# %% [markdown]
# # Reset index

# %%
yearFreq.reset_index(inplace=True, drop=True)
yearFreq.head()
# Out:
#    year frequency
# 0  ۱۳۳۷       818
# 1  ۱۳۴۵       557
# 2  ۱۳۴۸       926
# 3  ۱۳۵۵       620
# 4  ۱۳۵۷       766
